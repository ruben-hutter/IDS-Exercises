# %%
# Initialize Otter
import otter
grader = otter.Notebook("03-exercise-pids2023.ipynb")

# %% [markdown]
# # Exercise sheet 3
# **Hello everyone!**
#
# This is the second graded exercise sheet. <br>
#
# **Points: 21**
#
# Topics of this exercise sheet are:
# * Get confident with Jupyter, pandas
# * Matplotlib
# * Introduction to more advanced visualization tools
# * Search new functions on your own
#
# Please let us know if you have questions or problems! <br>
# Contact us during the exercise session, on [Piazza](https://piazza.com/class/leibdr4lk8n3w4), or [via email](https://sada.dmi.unibas.ch/en/teaching/pids23).
#
# Please submit this exercise sheet on **GRADESCOPE**.
# Naming conventions:
# * Name of notebook: "03-exercise-pids2023.ipynb"
#
# Your notebook will be automatically graded using gradescope. Before the exercise session, you should have received an email saying that you were registered to a course in gradescope. If this is not the case, please contact us.
#
# The sheet is released before the exercise session on Tuesday. You have until the next exercise session on Tuesday to submit this sheet. Most of the questions of the exercise sheet can be handle during the session.
#
# **Handout date**: 14.03.2023 <br>
# **Submission date**: 21.03.2023 before 16:00 <br>

# %% [markdown]
# ##  About this notebook
#
# In this notebook we will explore data on college majors sourced from the American Community Survey 2010–2012 Public Use Microdata Sample. This dataset can be found at this [URL](https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv).
#
#
# ### Please name the variables as suggested! Otherwise the grading system will fail you!

# %% [markdown]
# ---
# ## Question 1 (1 point)
#
# In this part you will load the dataset and have a rapid overview of what it looks like.

# %%
import pandas as pd
from nose.tools import assert_is_instance, assert_equal, assert_almost_equal, assert_true

# %% [markdown]
# Load the data in a Pandas dataframe using "read_csv" Pandas function.

# %%
download_url = ("https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/recent-grads.csv")
df = pd.read_csv(download_url)

# %% [markdown]
# Display the first 7 rows and **all the columns**. This will help you to have an idea of what is inside the dataset.

# %%
pd.set_option('display.max_columns', None)
df.head(7)
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
# 5     6        2418                        NUCLEAR ENGINEERING   2573.0
# 6     7        6202                          ACTUARIAL SCIENCE   3777.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
# 5   2200.0    373.0    Engineering    0.144967           17      1857
# 6   2110.0   1667.0       Business    0.441356           51      2912
#
#    Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# 0       1849        270                  1207          37           0.018381
# 1        556        170                   388          85           0.117241
# 2        558        133                   340          16           0.024096
# 3       1069        150                   692          40           0.050125
# 4      23170       5180                 16697        1672           0.061098
# 5       2038        264                  1449         400           0.177226
# 6       2924        296                  2482         308           0.095652
#
#    Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0  110000  95000  125000          1534               364            193
# 1   75000  55000   90000           350               257             50
# 2   73000  50000  105000           456               176              0
# 3   70000  43000   80000           529               102              0
# 4   65000  50000   75000         18314              4440            972
# 5   65000  50000  102000          1142               657            244
# 6   62000  53000   72000          1768               314            259

# %% [markdown]
# ## Question 2 (5 points)
#
# In this part we will plot basic information to get a sense of the dataset. ***You must use the pandas plot functions***. <br> (In genearl one could of course as well plot with matplotlib or similar BUT here we restrict us to the pandas plot for the sake of autograding.)
#
# For your information, "Rank" is the rank of the major by median earnings.

# %% [markdown]
# ### 2a)
# Does the unemployment rate look proportional to the rank of the major? Plot the unemployment rate ($y$ axis) against the rank of the major ($x$ axis).

# %%
plot_unemployed_rank = df.plot(x='Rank', y='Unemployment_rate', xlim=(1,173))

# %% [markdown]
# ### 2b)
# Does the salary look proportional to the rank of the major?
#
# Use **pandas plot function** to display the median salary, the 25th and 75th percentiles against the rank of the major ($x$ axis). Display everything in **one plot**.

# %%
plot_salary_rank = df.plot(x='Rank', y=['Median', 'P25th', 'P75th'], xlim=(1,173))

# %% [markdown]
# ### 2c)
# Using **pandas plot function**, plot the number of low wage jobs ($y$ axis) against the rank of the major ($x$ axis).

# %%
plot_lowwage_rank = df.plot(x='Rank', y='Low_wage_jobs', xlim=(1,173))

# %% [markdown]
# ### 2d)
#
# Can we make conclusions about the relation between low wage jobs and the rank of the Major?
#
# We will display the percentage of low wage jobs ($y$ axis) against the rank of the major ($x$ axis) and **use Matplotlib** to get a more precise plot.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Extract the colums containing:
#     - rank
#     - number of low wage jobs
#     - employed people
# from the data set and put each of them into their own series.

# %%
df_rank = df['Rank']
df_wage = df['Low_wage_jobs']
df_employed = df['Employed']

# %% [markdown]
# ### 2e)
# Using **matplotlib**, display the **percentage** of low wage jobs ($y$ axis) against the rank of the major ($x$ axis). Please make a variable containing the values of the y axis of your plot.
# **Hint:** use the variables 'df_wage' and 'df_employed' that you extracted previously.

# %%
percentage = df_wage / df_employed
plt.plot(df_rank, percentage)

# %% [markdown]
# ## Question 3 (3 points)
# In this part, we will get some information about the distribution of the data.

# %% [markdown]
# ### 3a) (1 point)
# Use **pandas plot** to display the histogram **with 18 bins** for the median salary.
#
# IMPORTANT: Estimate the height of the highest bin and assign your estimate to the variable **estimate**.

# %%
hist_median_column = df['Median'].plot.hist(bins=18)
estimate = 60

# %% [markdown]
# ### 3b) (2 points)
# Use matplotlib to do a subplot with two figures.<br>
# The first figure is the histogram for the median salary (like 3a but with matplotlib).<br>
# The second figure is the same histogram but with 30 bins, the color green, $x$ and $y$ labels and a grid.
#
# **Important:** Create a variable named *color_black* that contains a string with the corresponding farbcode (only ONE letter) used in matplotlib for black.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

ax1.hist(df['Median'], bins=18)
ax2.hist(df['Median'], bins=30, color='g')

ax1.set(xlabel='Median', ylabel='Ammount')
ax2.set(xlabel='Median', ylabel='Ammount')

color_black = 'k'

# %% [markdown]
# ## Question 4 (4 points)
# Based on the histogram that you displayed in the previous part, you should see some isolated extreme values.
# In this part, we will try to identify and understand these outliers.

# %% [markdown]
# ### 4a) (1 point)
# Extract a dataframe containing the rows with the 10 highest median salaries.

# %%
top_10 = df.sort_values('Median', ascending=False)[:10]
#top_10 = df.nlargest(n=10, columns='Median')
top_10
# Out:
#     Rank  Major_code                                      Major    Total  \
# 0      1        2419                      PETROLEUM ENGINEERING   2339.0
# 1      2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2      3        2415                  METALLURGICAL ENGINEERING    856.0
# 3      4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4      5        2405                       CHEMICAL ENGINEERING  32260.0
# 5      6        2418                        NUCLEAR ENGINEERING   2573.0
# 6      7        6202                          ACTUARIAL SCIENCE   3777.0
# 7      8        5001                 ASTRONOMY AND ASTROPHYSICS   1792.0
# 10    11        2407                       COMPUTER ENGINEERING  41542.0
# 13    14        5008                          MATERIALS SCIENCE   4279.0
#
#         Men    Women     Major_category  ShareWomen  Sample_size  Employed  \
# 0    2057.0    282.0        Engineering    0.120564           36      1976
# 1     679.0     77.0        Engineering    0.101852            7       640
# 2     725.0    131.0        Engineering    0.153037            3       648
# 3    1123.0    135.0        Engineering    0.107313           16       758
# 4   21239.0  11021.0        Engineering    0.341631          289     25694
# 5    2200.0    373.0        Engineering    0.144967           17      1857
# 6    2110.0   1667.0           Business    0.441356           51      2912
# 7     832.0    960.0  Physical Sciences    0.535714           10      1526
# 10  33258.0   8284.0        Engineering    0.199413          399     32506
# 13   2949.0   1330.0        Engineering    0.310820           22      3307
#
#     Full_time  Part_time  Full_time_year_round  Unemployed  Unemployment_rate  \
# 0        1849        270                  1207          37           0.018381
# 1         556        170                   388          85           0.117241
# 2         558        133                   340          16           0.024096
# 3        1069        150                   692          40           0.050125
# 4       23170       5180                 16697        1672           0.061098
# 5        2038        264                  1449         400           0.177226
# 6        2924        296                  2482         308           0.095652
# 7        1085        553                   827          33           0.021167
# 10      30315       5146                 23621        2275           0.065409
# 13       2751        878                  1967          78           0.023043
#
#     Median  P25th   P75th  College_jobs  Non_college_jobs  Low_wage_jobs
# 0   110000  95000  125000          1534               364            193
# 1    75000  55000   90000           350               257             50
# 2    73000  50000  105000           456               176              0
# 3    70000  43000   80000           529               102              0
# 4    65000  50000   75000         18314              4440            972
# 5    65000  50000  102000          1142               657            244
# 6    62000  53000   72000          1768               314            259
# 7    62000  31500  109000           972               500            220
# 10   60000  45000   75000         23694              5721            980
# 13   60000  39000   65000          2626               391             81

# %% [markdown]
# ### 4b) (1 point)
# For the majors with top 10 median salaries, display the median, the 25th and 75th percentiles on a bar plot.<br>
# **Hint**: Use the attribute 'kind' in the pandas plot function.

# %%
hist_major = top_10.plot(x='Major', y=['Median', 'P25th', 'P75th'], kind='bar')
hist_major
# Out:
# <AxesSubplot: xlabel='Major'>

# %% [markdown]
# ### 4c) (2 points)
# We can also create a histogram for a specific category. Display the histogram of the median salary for the Major with category "Engineering" **with 18 bins!**
#
# IMPORTANT: Estimate the height of the highest bin and assign your estimate to the variable **estimate2**.

# %%
hist_major_engineering = df[df['Major_category'] == 'Engineering']['Median'].plot.hist(bins=18)
estimate2 = 6

# %% [markdown]
# ## Question 5 (1 point)
# Let's now see if we can infer the correlation between two factors using scatter plots.

# %% [markdown]
# Using **pandas plot functions** plot the median salary ($x$ axis) against the unemployment rate on a scatter plot.<br>
# **Hint**: use once again the attribute 'kind' from the pandas plot function.

# %%
scatterplot = df.plot(x='Median', y='Unemployment_rate', kind='scatter')
scatterplot
# Out:
# <AxesSubplot: xlabel='Median', ylabel='Unemployment_rate'>

# %% [markdown]
# ## Question 6 (3 points)
# In this part, we will now see how to analyze and visualize categorical data.

# %% [markdown]
# We want to count how many students there are per category. <br>
# Extract the different categories (column "Major_category") and display them on an **horizontal** bar plot.<br>
# Sum up the number of students in each category (column "Total"). <br>
# **Hint**: use once again the attribute 'kind' from the pandas plot function as well as the function df.groupby().

# %%
cat_totals = df.groupby('Major_category')['Total'].sum()
cat_totals.plot(kind='barh')
# Out:
# <AxesSubplot: ylabel='Major_category'>

# %%
grader.check("Question 6")
# Out:
# Question 6 results: All test cases passed!

# %% [markdown]
# ---
#
# To double-check your work, the cell below will rerun all of the autograder tests.

# %%
grader.check_all()
# Out:
# Question 1 results: All test cases passed!
#
# Question 2a results: All test cases passed!
#
# Question 2b results: All test cases passed!
#
# Question 2c results: All test cases passed!
#
# Question 2d results: All test cases passed!
#
# Question 2e results: All test cases passed!
#
# Question 3a results: All test cases passed!
#
# Question 3b results: All test cases passed!
#
# Question 4a results: All test cases passed!
#
# Question 4b results: All test cases passed!
#
# Question 4c results: All test cases passed!
#
# Question 5 results: All test cases passed!
#
# Question 6 results: All test cases passed!

# %% [markdown]
# ## Submission
#
# Make sure you have run all cells in your notebook in order before running the cell below, so that all images/graphs appear in the output. The cell below will generate a zip file for you to submit. **Please save before exporting!**

# %%
# Save your notebook first, then run this cell to export your submission.
grader.export()
# Out:
# ---------------------------------------------------------------------------
# LatexFailed                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/otter/export/exporters/via_latex.py:69, in PDFViaLatexExporter.convert_notebook(cls, nb_path, dest, xecjk, no_xecjk, **kwargs)
#      67         output_file.write(latex_output[0])
# ---> 69 pdf_output = nbconvert.export(pdf_exporter, nb)
#      70 with open(dest, "wb") as output_file:
#
# File ~/.local/lib/python3.10/site-packages/nbconvert/exporters/base.py:90, in export(exporter, nb, **kw)
#      89 if isinstance(nb, NotebookNode):
# ---> 90     output, resources = exporter_instance.from_notebook_node(nb, resources)
#      91 elif isinstance(nb, (str,)):
#
# File ~/.local/lib/python3.10/site-packages/nbconvert/exporters/pdf.py:200, in PDFExporter.from_notebook_node(self, nb, resources, **kw)
#     199 if not os.path.isfile(pdf_file):
# --> 200     raise LatexFailed("\n".join(self._captured_output))
#     201 self.log.info("PDF successfully created")
#
# LatexFailed: PDF creating failed, captured latex output:
# This is BibTeX, Version 0.99d (TeX Live 2022/Arch Linux)
# The top-level auxiliary file: notebook.aux
# I found no \citation commands---while reading file notebook.aux
# I found no \bibdata command---while reading file notebook.aux
# I found no \bibstyle command---while reading file notebook.aux
# (There were 3 error messages)
#
#
# During handling of the above exception, another exception occurred:
#
# LatexFailed                               Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/otter/export/exporters/via_latex.py:69, in PDFViaLatexExporter.convert_notebook(cls, nb_path, dest, xecjk, no_xecjk, **kwargs)
#      67         output_file.write(latex_output[0])
# ---> 69 pdf_output = nbconvert.export(pdf_exporter, nb)
#      70 with open(dest, "wb") as output_file:
#
# File ~/.local/lib/python3.10/site-packages/nbconvert/exporters/base.py:90, in export(exporter, nb, **kw)
#      89 if isinstance(nb, NotebookNode):
# ---> 90     output, resources = exporter_instance.from_notebook_node(nb, resources)
#      91 elif isinstance(nb, (str,)):
#
# File ~/.local/lib/python3.10/site-packages/nbconvert/exporters/pdf.py:194, in PDFExporter.from_notebook_node(self, nb, resources, **kw)
#     193 self.log.info("Building PDF")
# --> 194 self.run_latex(tex_file)
#     195 if self.run_bib(tex_file):
#
# File ~/.local/lib/python3.10/site-packages/nbconvert/exporters/pdf.py:163, in PDFExporter.run_latex(self, filename, raise_on_failure)
#     161     self.log.critical("%s failed: %s\n%s", command[0], command, out)
# --> 163 return self.run_command(
#     164     self.latex_command, filename, self.latex_count, log_error, raise_on_failure
#     165 )
#
# File ~/.local/lib/python3.10/site-packages/nbconvert/exporters/pdf.py:153, in PDFExporter.run_command(self, command_list, filename, count, log_function, raise_on_failure)
#     152 if raise_on_failure:
# --> 153     raise raise_on_failure(f'Failed to run "{command}" command:\n{out_str}')
#     154 return False  # failure
#
# LatexFailed: PDF creating failed, captured latex output:
# Failed to run "['xelatex', 'notebook.tex', '-quiet']" command:
# This is XeTeX, Version 3.141592653-2.6-0.999994 (TeX Live 2022/Arch Linux) (preloaded format=xelatex)
#  restricted \write18 enabled.
# entering extended mode
# (./notebook.tex
# LaTeX2e <2021-11-15> patch level 1
# L3 programming layer <2022-04-10>
# (/usr/share/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
# (/usr/share/texmf-dist/tex/latex/base/size10.clo))
# (/usr/share/texmf-dist/tex/xelatex/xecjk/xeCJK.sty
# (/usr/share/texmf-dist/tex/latex/l3kernel/expl3.sty
# (/usr/share/texmf-dist/tex/latex/l3backend/l3backend-xetex.def))
#
# ! LaTeX Error: File `ctexhook.sty' not found.
#
# Type X to quit or <RETURN> to proceed,
# or enter new name. (Default extension: sty)
#
# Enter file name:
# ! Emergency stop.
# <read *>
#
# l.55 \prg_new_conditional:Npnn
#                                \xeCJK_if_package_loaded:n #1 { p , T , F , T...
#
# No pages of output.
# Transcript written on notebook.log.
#
#
# During handling of the above exception, another exception occurred:
#
# ExportFailedException                     Traceback (most recent call last)
# Cell In[195], line 2
#       1 # Save your notebook first, then run this cell to export your submission.
# ----> 2 grader.export()
#
# File ~/.local/lib/python3.10/site-packages/otter/check/utils.py:156, in grading_mode_disabled(wrapped, self, args, kwargs)
#     154 if type(self)._grading_mode:
#     155     return
# --> 156 return wrapped(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/otter/check/utils.py:143, in incompatible_with.<locals>.incompatible(wrapped, self, args, kwargs)
#     141     else:
#     142         return
# --> 143 return wrapped(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/otter/check/utils.py:193, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     191 except Exception as e:
#     192     self._log_event(event_type, success=False, error=e)
# --> 193     raise e
#     195 else:
#     196     self._log_event(event_type, results=results, question=question, shelve_env=shelve_env)
#
# File ~/.local/lib/python3.10/site-packages/otter/check/utils.py:187, in logs_event.<locals>.event_logger(wrapped, self, args, kwargs)
#     184     question, results, shelve_env = wrapped(*args, **kwargs)
#     186 else:
# --> 187     results = wrapped(*args, **kwargs)
#     188     shelve_env = {}
#     189     question = None
#
# File ~/.local/lib/python3.10/site-packages/otter/check/notebook.py:380, in Notebook.export(self, nb_path, export_path, pdf, filtering, pagebreaks, files, display_link, force_save, run_tests)
#     377 zf.write(nb_path)
#     379 if pdf:
# --> 380     pdf_path = export_notebook(nb_path, filtering=filtering, pagebreaks=pagebreaks)
#     381     if os.path.isfile(pdf_path):
#     382         zf.write(pdf_path)
#
# File ~/.local/lib/python3.10/site-packages/otter/export/__init__.py:42, in export_notebook(nb_path, dest, exporter_type, **kwargs)
#      39     pdf_name = os.path.splitext(nb_path)[0] + ".pdf"
#      41 Exporter = get_exporter(exporter_type=exporter_type)
# ---> 42 Exporter.convert_notebook(nb_path, pdf_name, **kwargs)
#      44 return pdf_name
#
# File ~/.local/lib/python3.10/site-packages/otter/export/exporters/via_latex.py:75, in PDFViaLatexExporter.convert_notebook(cls, nb_path, dest, xecjk, no_xecjk, **kwargs)
#      73 except nbconvert.pdf.LatexFailed as error:
#      74     if not xecjk and not no_xecjk:
# ---> 75         cls.convert_notebook(nb_path, dest, xecjk=True, **kwargs)
#      77     else:
#      78         message = "There was an error generating your LaTeX; showing full error message:\n"
#
# File ~/.local/lib/python3.10/site-packages/otter/export/exporters/via_latex.py:84, in PDFViaLatexExporter.convert_notebook(cls, nb_path, dest, xecjk, no_xecjk, **kwargs)
#      80         if xecjk:
#      81             message += "\n\nIf the error above is related to xeCJK or fandol in LaTeX " \
#      82                 "and you don't require this functionality, try running again with " \
#      83                 "no_xecjk set to True or the --no-xecjk flag."
# ---> 84         raise ExportFailedException(message)
#      86 finally:
#      87     if NBCONVERT_6:
#
# ExportFailedException: There was an error generating your LaTeX; showing full error message:
#     Failed to run "['xelatex', 'notebook.tex', '-quiet']" command:
#     This is XeTeX, Version 3.141592653-2.6-0.999994 (TeX Live 2022/Arch Linux) (preloaded format=xelatex)
#      restricted \write18 enabled.
#     entering extended mode
#     (./notebook.tex
#     LaTeX2e <2021-11-15> patch level 1
#     L3 programming layer <2022-04-10>
#     (/usr/share/texmf-dist/tex/latex/base/article.cls
#     Document Class: article 2021/10/04 v1.4n Standard LaTeX document class
#     (/usr/share/texmf-dist/tex/latex/base/size10.clo))
#     (/usr/share/texmf-dist/tex/xelatex/xecjk/xeCJK.sty
#     (/usr/share/texmf-dist/tex/latex/l3kernel/expl3.sty
#     (/usr/share/texmf-dist/tex/latex/l3backend/l3backend-xetex.def))
#
#     ! LaTeX Error: File `ctexhook.sty' not found.
#
#     Type X to quit or <RETURN> to proceed,
#     or enter new name. (Default extension: sty)
#
#     Enter file name:
#     ! Emergency stop.
#     <read *>
#
#     l.55 \prg_new_conditional:Npnn
#                                    \xeCJK_if_package_loaded:n #1 { p , T , F , T...
#
#     No pages of output.
#     Transcript written on notebook.log.
#
#
# If the error above is related to xeCJK or fandol in LaTeX and you don't require this functionality, try running again with no_xecjk set to True or the --no-xecjk flag.
